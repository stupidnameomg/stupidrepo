# %%
import numpy as np
import matplotlib.pyplot as plt 
import deeptrack as dp
# %matplotlib inline

# %% [markdown]
# # Super sick stuff

# %%
x = np.linspace(0,2*np.pi,1000)
y = np.sin(x)

my_fig = plt.figure()
my_ax = my_fig.add_subplot(1,1,1)
my_ax.plot(x, y)
